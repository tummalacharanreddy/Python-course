# %%
num=int(input('enter number'))

if (num%2==0):
    print('even number {}'.format(num))
elif (num%5==0):
    print('5 multiples number {}'.format(num))
else:
    print('odd number {}'.format(num))
# Out:
# enter number10
# even number 10

# %%
i=0
for i in range(5):
    print(i)
    i+=1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
i=0
while i<=5:
    print(i)
    i+=1
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
x=[1,2,3]
y=[]

[x+1 for i in x]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21200\323693156.py in <module>
#       2 y=[]
#       3
# ----> 4 [x+1 for i in x]
#
# ~\AppData\Local\Temp\ipykernel_21200\323693156.py in <listcomp>(.0)
#       2 y=[]
#       3
# ----> 4 [x+1 for i in x]
#
# TypeError: can only concatenate list (not "int") to list
